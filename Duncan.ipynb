# %%
import numpy as np
y=[1]
for i in range(0,2):
 t=23*y[i]
 y.append(t)
y
# Out:
# [1, 23, 529]

# %%
def sequencer(M,N,q,x0):
  y=[x0]
  for i in range(0,N):
    t=M*y[i]**q
    y.append(t)

  return y
x=sequencer(2,5,2,1)
x
# Out:
# [1, 2, 8, 128, 32768, 2147483648]

# %%
def sequencer(M,N,q,x0):
  y=[x0]*N
  t=M*y[i]**q
    y.append(t)

  return y
x=sequencer(2,5,2,1)
x
# Out:
# [2, 2, 2, 2, 2]
