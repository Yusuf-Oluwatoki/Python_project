# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as se
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
TDA=pd.read_csv('/content/gdrive/My Drive/Deep/export_TDA06-12-2020_09-11-2020.csv')
TDA.head(3)
# Out:
#                             comb_id  converted  ...  view brochure  visualizer start
# 0  00004041b8c8380b13a8ebfaa552ac46          0  ...              0                 0
# 1  0000fc3f4989cb0a552d7cc5a673088d          0  ...              0                 0
# 2  00010b5e78400d303bda58ae6ae753ba          0  ...              0                 0
#
# [3 rows x 88 columns]

# %%
TDA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056454 entries, 0 to 1056453
# Data columns (total 88 columns):
#  #   Column                                Non-Null Count    Dtype
# ---  ------                                --------------    -----
#  0   comb_id                               1056454 non-null  object
#  1   converted                             1056454 non-null  int64
#  2   visit_num                             1056454 non-null  int64
#  3   cnt_campaigns                         1056454 non-null  int64
#  4   mobile_flag                           1056454 non-null  int64
#  5   visitor_length                        1056454 non-null  int64
#  6   CON-Add recommendation                1056454 non-null  int64
#  7   Saved Configuration                   1056454 non-null  int64
#  8   change model                          1056454 non-null  int64
#  9   open form: CONTACT form               1056454 non-null  int64
# ...

# %%
CON=pd.read_csv('/content/gdrive/My Drive/Deep/export_CON06-12-2020_09-11-2020.csv')
CON.head(3)
# Out:
#                             comb_id  converted  ...  view brochure  visualizer start
# 0  00001b0f35380a164a329475fa0c2f6b          0  ...              0                 0
# 1  00015728122d103caf3de54d4ff09fa4          0  ...              0                 0
# 2  0001795bd790b1c13e580b9b3d1365c7          1  ...              0                 0
#
# [3 rows x 88 columns]

# %%
CON.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037540 entries, 0 to 1037539
# Data columns (total 88 columns):
#  #   Column                                Non-Null Count    Dtype
# ---  ------                                --------------    -----
#  0   comb_id                               1037540 non-null  object
#  1   converted                             1037540 non-null  int64
#  2   visit_num                             1037540 non-null  int64
#  3   cnt_campaigns                         1037540 non-null  int64
#  4   mobile_flag                           1037540 non-null  int64
#  5   visitor_length                        1037540 non-null  int64
#  6   CON-Add recommendation                1037540 non-null  int64
#  7   Saved Configuration                   1037540 non-null  int64
#  8   change model                          1037540 non-null  int64
#  9   open form: CONTACT form               1037540 non-null  int64
# ...

# %%
Electric=pd.read_csv('/content/gdrive/My Drive/Deep/export_Electric_RFO06-12-2020_09-11-2020.csv')
Electric.head(3)
# Out:
#                             comb_id  converted  ...  view brochure  visualizer start
# 0  ca7e5e8f1a839c6f9bb6721d59b49f01          0  ...              0                 0
# 1  ca7e7441b1d9c2d9c7b8253b15b8acee          0  ...              0                 0
# 2  ca7f67a68e1ca3634e2d7b7a167ea77f          0  ...              0                 0
#
# [3 rows x 88 columns]

# %%
Electric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056465 entries, 0 to 1056464
# Data columns (total 88 columns):
#  #   Column                                Non-Null Count    Dtype
# ---  ------                                --------------    -----
#  0   comb_id                               1056465 non-null  object
#  1   converted                             1056465 non-null  int64
#  2   visit_num                             1056465 non-null  int64
#  3   cnt_campaigns                         1056465 non-null  int64
#  4   mobile_flag                           1056465 non-null  int64
#  5   visitor_length                        1056465 non-null  int64
#  6   CON-Add recommendation                1056465 non-null  int64
#  7   Saved Configuration                   1056465 non-null  int64
#  8   change model                          1056465 non-null  int64
#  9   open form: CONTACT form               1056465 non-null  int64
# ...

# %%
RFO=pd.read_csv('/content/gdrive/My Drive/Deep/export_RFO06-12-2020_09-11-2020.csv')
RFO.head(3)
# Out:
#                             comb_id  converted  ...  view brochure  visualizer start
# 0  ad26fb4dc594039e852c90eec2cf43ea          0  ...              0                 0
# 1  ad27c18e33ee8f78d7a2a32e0a1e38d2          0  ...              0                 0
# 2  ad27ecd3416925a08e98e2bcd54d1640          0  ...              0                 0
#
# [3 rows x 88 columns]

# %%
RFO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056458 entries, 0 to 1056457
# Data columns (total 88 columns):
#  #   Column                                Non-Null Count    Dtype
# ---  ------                                --------------    -----
#  0   comb_id                               1056458 non-null  object
#  1   converted                             1056458 non-null  int64
#  2   visit_num                             1056458 non-null  int64
#  3   cnt_campaigns                         1056458 non-null  int64
#  4   mobile_flag                           1056458 non-null  int64
#  5   visitor_length                        1056458 non-null  int64
#  6   CON-Add recommendation                1056458 non-null  int64
#  7   Saved Configuration                   1056458 non-null  int64
#  8   change model                          1056458 non-null  int64
#  9   open form: CONTACT form               1056458 non-null  int64
# ...

# %%
RFI=pd.read_csv('/content/gdrive/My Drive/Deep/export_RFI06-12-2020_09-11-2020.csv')
RFI.head(3)
# Out:
#                             comb_id  converted  ...  view brochure  visualizer start
# 0  0001046fa7f619a7d62c52d0edd9987f          0  ...              0                 0
# 1  000166b9ed0641dd4963aa491dcfca12          0  ...              0                 0
# 2  0003636a90f85efe178483e11b3e7847          0  ...              0                 0
#
# [3 rows x 88 columns]

# %%
RFI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056433 entries, 0 to 1056432
# Data columns (total 88 columns):
#  #   Column                                Non-Null Count    Dtype
# ---  ------                                --------------    -----
#  0   comb_id                               1056433 non-null  object
#  1   converted                             1056433 non-null  int64
#  2   visit_num                             1056433 non-null  int64
#  3   cnt_campaigns                         1056433 non-null  int64
#  4   mobile_flag                           1056433 non-null  int64
#  5   visitor_length                        1056433 non-null  int64
#  6   CON-Add recommendation                1056433 non-null  int64
#  7   Saved Configuration                   1056433 non-null  int64
#  8   change model                          1056433 non-null  int64
#  9   open form: CONTACT form               1056433 non-null  int64
# ...

# %%
#full=pd.read_csv('/content/gdrive/My Drive/Deep/raw_export_no_header.psv', sep='|', header=None, error_bad_lines=False)
#full.head(3)

# %%
#chunksize = 10 ** 6
#filename= '/content/gdrive/My Drive/Deep/raw_export_no_header.psv'
#full=pd.read_csv('/content/gdrive/My Drive/Deep/raw_export_no_header.psv', sep='|', header=None, error_bad_lines=False)

#for chunk in pd.read_csv(filename, chunksize=chunksize, sep='|', header=None, error_bad_lines=False):
 #   print("DataType: {} Shape: {} Memory: {}".format(type(chunk),
  #                                             chunk.shape, 
   #                                            chunk.memory_usage().sum()))

# %%
raw_head=pd.read_csv('/content/gdrive/My Drive/Deep/raw_data_header.csv')
raw_head
# Out:
# Empty DataFrame
# Columns: [comb_id_hash, visit_num, visit_page_num, date_time, post_evar24, prop56, prop56_trck, prop58, prop60, prop62, campaign, os]
# Index: []

# %%
chunksize = 10 ** 3
filename= '/content/gdrive/My Drive/Deep/raw_export_no_header.psv'
#names=["Sequence", "Start", "End", "Coverage"]
tp=pd.read_csv(filename,  sep='|',iterator=True, chunksize=chunksize,   header=None, error_bad_lines=False)

df=pd.DataFrame(tp.get_chunk(1005))
df.columns=[raw_head]
blankIndex=[''] * len(df)
df.index=blankIndex
df.head(3)
# Out:
# b'Skipping line 34: expected 12 fields, saw 13\nSkipping line 35: expected 12 fields, saw 13\nSkipping line 45: expected 12 fields, saw 13\nSkipping line 46: expected 12 fields, saw 13\nSkipping line 49: expected 12 fields, saw 14\nSkipping line 50: expected 12 fields, saw 13\nSkipping line 52: expected 12 fields, saw 13\nSkipping line 53: expected 12 fields, saw 14\nSkipping line 54: expected 12 fields, saw 13\nSkipping line 70: expected 12 fields, saw 13\nSkipping line 71: expected 12 fields, saw 13\nSkipping line 72: expected 12 fields, saw 13\nSkipping line 76: expected 12 fields, saw 13\nSkipping line 89: expected 12 fields, saw 13\nSkipping line 90: expected 12 fields, saw 14\nSkipping line 91: expected 12 fields, saw 14\nSkipping line 92: expected 12 fields, saw 13\nSkipping line 93: expected 12 fields, saw 13\nSkipping line 94: expected 12 fields, saw 13\nSkipping line 97: expected 12 fields, saw 14\nSkipping line 98: expected 12 fields, saw 14\nSkipping line 99: expected 12 
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1005 entries,  to
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (comb_id_hash,)    1005 non-null   object
#  1   (visit_num,)       1005 non-null   object
#  2   (visit_page_num,)  1001 non-null   float64
#  3   (date_time,)       1005 non-null   object
#  4   (post_evar24,)     987 non-null    object
#  5   (prop56,)          768 non-null    object
#  6   (prop56_trck,)     1001 non-null   object
#  7   (prop58,)          116 non-null    object
#  8   (prop60,)          764 non-null    object
#  9   (prop62,)          762 non-null    object
#  10  (campaign,)        249 non-null    object
#  11  (os,)              997 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 102.1+ KB

# %%
chunksize = 10 ** 3
filename= '/content/gdrive/My Drive/Deep/recently_used_events_for_modelling.psv'
#names=["Sequence", "Start", "End", "Coverage"]
tp=pd.read_csv(filename,  sep='|',  header=None, error_bad_lines=False)
tp.head(50)
# Out:
#                                                     0  1
# 0                              CON-Add recommendation  1
# 1                                 Saved Configuration  1
# 2                                    ac accessory add  0
# 3                                            ac print  0
# 4                                        ac step view  0
# 5                                      Arrow > 777184  0
# 6                                        change model  1
# 7                                 Laufleistung p.a. -  0
# 8                                          Laufzeit -  0
# 9                                         login start  0
# 10                             login success_electric  0
# 11                            open form: CONTACT form  1
# 12                       open form: KMI form_electric  1
# 13                   open form: OFFERFORBUSINESS form  1
# 14  Option Transfer Layer Click on No Transfer Button  0
# ...

# %%
tp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       184 non-null    object
#  1   1       184 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 3.0+ KB
