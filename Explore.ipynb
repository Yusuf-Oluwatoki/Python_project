# %% [markdown]
# #Importing packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import scipy as sp
# %matplotlib inline

# %%
data= pd.read_csv('compare.csv')

data.head()
# Out:
#        date  total_prec1  max_temp1  total_prec  max_temp
# 0  1/1/1979          0.0       30.0    7.925209      28.8
# 1  1/2/1979          0.0       30.0    9.743439      28.8
# 2  1/3/1979          0.0       30.0    5.889397      28.2
# 3  1/4/1979          0.0       30.0    5.631255      28.3
# 4  1/5/1979          0.0       30.4    1.498575      29.0

# %%
plt.scatter(data.total_prec1, data.total_prec)

# %%
np.corrcoef(data.total_prec1, data.total_prec)
# Out:
# array([[nan, nan],
#        [nan,  1.]])

# %%
plt.scatter(data.max_temp, data.max_temp1)

# %%
np.corrcoef(data.max_temp, data.max_temp1)
# Out:
# array([[ 1., nan],
#        [nan, nan]])

# %%
pd.scatter_matrix(data.total_prec1, data.total_prec)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-7f2e2a171069> in <module>()
#       1
# ----> 2 pd.scatter_matrix(data.total_prec1, data.total_prec)
#       3 plt.show()
#
# AttributeError: module 'pandas' has no attribute 'scatter_matrix'

# %%
pd.scatter_matrix(data.max_temp, data.max_temp1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-3ded4693f5b0> in <module>()
# ----> 1 pd.scatter_matrix(data.max_temp, data.max_temp1)
#       2 plt.show()
#
# AttributeError: module 'pandas' has no attribute 'scatter_matrix'
